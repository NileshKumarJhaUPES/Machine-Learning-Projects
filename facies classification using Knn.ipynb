# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

np.set_printoptions(precision=2)
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

np.set_printoptions(precision=2)
from pandas import set_option
set_option("display.max_rows", 10)
data = pd.read_csv('facies_vectors.csv')
data
# Out:
#       Facies Formation        Well Name   Depth      GR  ILD_log10  DeltaPHI  \
# 0          3     A1 SH        SHRIMPLIN  2793.0  77.450      0.664     9.900
# 1          3     A1 SH        SHRIMPLIN  2793.5  78.260      0.661    14.200
# 2          3     A1 SH        SHRIMPLIN  2794.0  79.050      0.658    14.800
# 3          3     A1 SH        SHRIMPLIN  2794.5  86.100      0.655    13.900
# 4          3     A1 SH        SHRIMPLIN  2795.0  74.580      0.647    13.500
# ...      ...       ...              ...     ...     ...        ...       ...
# 4144       5      C LM  CHURCHMAN BIBLE  3120.5  46.719      0.947     1.828
# 4145       5      C LM  CHURCHMAN BIBLE  3121.0  44.563      0.953     2.241
# 4146       5      C LM  CHURCHMAN BIBLE  3121.5  49.719      0.964     2.925
# 4147       5      C LM  CHURCHMAN BIBLE  3122.0  51.469      0.965     3.083
# 4148       5      C LM  CHURCHMAN BIBLE  3122.5  50.031      0.970     2.609
#
#        PHIND     PE  NM_M  RELPOS
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-685c88bba32b> in <module>
# ----> 1 training_data = pd.read_csv(filename)
#       2 training_data
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
data['Well Name'] = data['Well Name'].astype('category')
data['Formation'] = data['Formation'].astype('category')
data['Well Name'].unique()
# Out:
# [SHRIMPLIN, ALEXANDER D, SHANKLE, LUKE G U, KIMZEY A, CROSS H CATTLE, NOLAN, Recruit F9, NEWBY, CHURCHMAN BIBLE]
# Categories (10, object): [SHRIMPLIN, ALEXANDER D, SHANKLE, LUKE G U, ..., NOLAN, Recruit F9, NEWBY, CHURCHMAN BIBLE]

# %%
feature_names_data = ['Depth', 'GR', 'ILD_log10', 'DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS']
X_data = data[feature_names_data]
y_data = data['Facies']
target_names_data = ['Facies']

# %%
np.where(X_data >= np.finfo(np.float64).max)


X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()
# Scaling down both train and test data set
X_train_minmax=min_max.fit_transform(X_train[['Depth', 'GR', 'ILD_log10', 'DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS']])
X_test_minmax=min_max.fit_transform(X_test[['Depth', 'GR', 'ILD_log10', 'DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS']])

knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train_minmax,y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train_minmax,y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test_minmax,y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.83
# Accuracy of K-NN classifier on test set: 0.73
